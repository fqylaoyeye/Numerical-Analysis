# %%
import Pkg; Pkg.add("Polynomials")
# Out:
#     Updating registry at `~/.julia/registries/General.toml`
#    Resolving package versions...
#    Installed Polynomials ─ v3.2.4
#     Updating `~/.julia/environments/v1.8/Project.toml`
#   [f27b6e38] + Polynomials v3.2.4
#     Updating `~/.julia/environments/v1.8/Manifest.toml`
#   [f27b6e38] + Polynomials v3.2.4
# Precompiling
# project...
#   ✓ Polynomials
#   1 dependency successfully precompiled in 15 seconds. 134 already precompiled.

# %%
f(x)=exp(sin(2 π*x)) (cos(2 π*x))^2 - exp(sin(2 π*x)) sin(2 π*x)

import Polynomials

X=range(0, 1, length=10)
q= Polynomials.fit(X,f.(X))

# %%
import Polynomials

x=Polynomials.Polynomial([0,1])
Polynomials.integrate(x)
# Out:
# Polynomials.Polynomial(0.5*x^2)

# %%
import Polynomials
import Plots
ϵ =0.01
n=20
f(x)=tanh((x+1/2)/ϵ)+tanh(x/ϵ)+tanh((x-1/2)/ϵ)

equidistant_nodes = LinRange(-1,1,n+1)
chebyshev_nodes = [cos((2*i+1)* π/(2*n+2)) for i in 0:n]
p=Polynomials.fit(equidistant_nodes, f.(equidistant_nodes))
q=Polynomials.fit(chebyshev_nodes,f.(chebyshev_nodes))

x=LinRange(-1,1,1000)
Plots.plot(x,[f.(x),q.(x)])
