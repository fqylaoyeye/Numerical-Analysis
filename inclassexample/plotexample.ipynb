# %%
using Plots

plot(cos)

# %%
import Pkg; Pkg.add("Plots")
using Plots
plot(cos)
# Out:
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.8/Project.toml`
#   No Changes to `~/.julia/environments/v1.8/Manifest.toml`
# InterruptException:
#
#
#
# Stacktrace:
#
#   [1] read(s::IOStream)
#
#     @ Base ./iostream.jl:525
#
#   [2] read
#
#     @ ./io.jl:1004 [inlined]
#
#   [3] #387
#
#     @ ./io.jl:462 [inlined]
#
#   [4] open(f::Base.var"#387#388"{String}, args::String; kwargs::Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}})
#
#     @ Base ./io.jl:384
#
#   [5] open
#
#     @ ./io.jl:381 [inlined]
#
#   [6] read
#
#     @ ./io.jl:462 [inlined]
#
#   [7] precompile(ctx::Pkg.Types.Context, pkgs::Vector{String}; internal_call::Bool, strict::Bool, warn_loaded::Bool, already_instantiated::Bool, kwargs::Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}})
#
#     @ Pkg.API /Applications/Julia-1.8.app/Contents/Resources/julia/share/julia/stdlib/v1.8/Pkg/src/API.jl:1285
#
#   [8] #_auto_precompile#7
#
# ...

# %%
function diff(X,Y)
   if size(Y,1) == 1
      return y[1]
   end
   #([u1,...,u_n)]-[u0,...,u_(n-1))])/(xn-x0)
   num=diff(X[2:end],Y[2:end])-diff(X[2:end-1],Y[2:end-1])
   den=X[end]-X[1]
   return num/den
end

# %%
# Out:
# 0.1
